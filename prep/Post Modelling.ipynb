# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# %%
results = pd.read_pickle("crf_test_results.pkl")

# %%
predicted = results[results.pred == "signature"]

# %%
for name, group in predicted.groupby("filename"):
    print(group.loc[:, ["line", "person", "org", "email", "url", "phone"]])
    print()
# Out:
#        line  person  org  email  url  phone
# 4  Ka'Tina-  0       0    0      0    0
#
#      line  person  org  email  url  phone
# 11  Jenny  0       1    0      0    0
#
#                          line  person  org  email  url  phone
# 21  Many Thanks,               0       0    0      0    0
# 22                             0       0    0      0    0
# 23  Liz Taylor                 1       0    0      0    0
# 24  Assistant to Greg Whalley  0       0    0      0    0
# 25  713.853.1935 office        0       0    0      0    1
# 26  713.853.1838 fax           0       0    0      0    1
# 27  713.854.3056 mobile        0       0    0      0    1
#
#     line  person  org  email  url  phone
# 30  Lisa  0       0    0      0    0
#
#           line  person  org  email  url  phone
# 37  Thanks,     0       0    0      0    0
# 39  Danielle    1       0    0      0    0
#
#    line  person  org  email  url  phone
# 47  GT   0       0    0      0    0
#
#          line  person  org  email  url  phone
# 83  Thank you  0       0    0      0    0
# 84  Garrett    1       0    0      0    0
#
#                                line  person  org  email  url  phone
# 91  Thanks,                          0       0    0      0    0
# 92                                   0       0    0      0    0
# 93  Stacey                           0       0    0      0    0
# 94  Stacey L. Wales                  1       0    0      0    0
# 95                                   0       0    0      0    0
# 96  Stacey Wales                     1       0    0      0    0
# 97  Origination Transaction Support  0       0    0      0    0
# 98  Enron Industrial Markets         0       1    0      0    0
# 99  713-345-7186                     0       0    0      0    1
#
#         line  person  org  email  url  phone
# 102  Thanks.  0       0    0      0    0
# 103  Donna    1       0    0      0    0
#
#                                line  person  org  email  url  phone
# 121  Thank you;                      0       0    0      0    0
# 122  Cheri Thomas                    1       0    0      0    0
# 123  Transmission & Energy Services  0       1    0      0    0
# 124  503.464-5078                    0       0    0      0    1
# 125  503.464-8178, fax               0       0    0      0    1
# 126  503.803.1885, cell              0       0    0      0    1
# 127  E-mail: "Cheri_thomas@pgn.com"  0       0    1      1    0
# 129  3WTC-0506                       0       0    0      0    1
# 130  121 SW Salmon Street            0       0    0      0    0
# 131  Portland, Oregon  97204         0       0    0      0    1
#
#         line  person  org  email  url  phone
# 136  Thanks,  0       0    0      0    0
# 137  Ryan     1       0    0      0    0
#
#                line  person  org  email  url  phone
# 142  - Frank, OATI   0       0    0      0    0
#
#                                                                          line  \
# 152  Cara Semperger
# 153  Mike Purcell
# 154  Serena Bishop
# 157  Thank You.
# 158
# 159
# 160  **********************************************************************
# 161  This e-mail is the property of Enron Corp. and/or its relevant affiliate
# 162  and may contain confidential and privileged material for the sole use of
# 163  the intended recipient (s). Any review, use, distribution or disclosure
# 164  by others is strictly prohibited. If you are not the intended recipient
# 165  (or authorized to receive for the recipient), please contact the sender
# 166  or reply to Enron Corp. at enron.messaging.administration@enron.com and
# 167  delete all copies of the message. This e-mail (and any attachments
# 168  hereto) are not intended to be an offer (or an acceptance) and do not
# 169  create or evidence a binding and enforceable contract between Enron
# 170  Corp. (or any of its affiliates) and the intended recipient or any other
# 171  party, and may not be relied on by anyone as the basis of a contract by
# 172  estoppel or otherwise. Thank you.
# 173  **********************************************************************
#
#      person  org  email  url  phone
# 152  1       0    0      0    0
# 153  1       0    0      0    0
# 154  1       0    0      0    0
# 157  0       0    0      0    0
# 158  0       0    0      0    0
# 159  0       0    0      0    0
# 160  0       0    0      0    0
# 161  0       0    0      0    0
# 162  0       0    0      0    0
# 163  0       0    0      0    0
# 164  0       0    0      0    0
# 165  0       0    0      0    0
# 166  0       1    1      1    0
# 167  0       0    0      0    0
# 168  0       0    0      0    0
# 169  0       0    0      0    0
# 170  0       0    0      0    0
# 171  0       0    0      0    0
# 172  0       0    0      0    0
# 173  0       0    0      0    0
#
#                              line  person  org  email  url  phone
# 208  Carol Moline                  0       1    0      0    0
# 209  Financial Controller          0       0    0      0    0
# 210  Power Pool of Alberta         0       0    0      0    0
# 211  (403) 233-4686                0       0    0      0    1
# 212  carol.moline@powerpool.ab.ca  0       0    1      1    0
#
#        line  person  org  email  url  phone
# 215  Jeff    1       0    0      0    0
#
#            line  person  org  email  url  phone
# 220    Virginia  0       0    0      0    0
#
#         line  person  org  email  url  phone
# 224  Thanks,  0       0    0      0    0
# 225  Elsie    0       1    0      0    0
#
#         line  person  org  email  url  phone
# 228  Thanks,  0       0    0      0    0
# 229  Elsie    0       1    0      0    0
#
#       line  person  org  email  url  phone
# 236  Jenny  0       1    0      0    0
#
#               line  person  org  email  url  phone
# 239  [Gang, Lisa]   0       0    0      0    0
#
#         line  person  org  email  url  phone
# 242  Thanks,  0       0    0      0    0
# 243  Elsie    0       1    0      0    0
#
#         line  person  org  email  url  phone
# 256  Ken Lay  1       0    0      0    0
#
#                           line  person  org  email  url  phone
# 272  Enron Benefits Department  0       1    0      0    0
#
#                                                                            line  \
# 313  ------------------------ Yahoo! Groups Sponsor ---------------------~-->
# 314  Get your FREE credit report with a FREE CreditCheck
# 315  Monitoring Service trial
# 316  http://us.click.yahoo.com/ACHqaB/bQ8CAA/ySSFAA/9rHolB/TM
# 317  ---------------------------------------------------------------------~->
# 318
# 319  To unsubscribe from this group, send an email to:
# 320  ASME-OMAE-Houston-unsubscribe@egroups.com
# 321
# 322
# 323
# 324  Your use of Yahoo! Groups is subject to http://docs.yahoo.com/info/terms/
#
#      person  org  email  url  phone
# 313  0       0    0      0    0
# 314  0       0    0      0    0
# 315  0       0    0      0    0
# 316  0       0    0      1    0
# 317  0       0    0      0    0
# 318  0       0    0      0    0
# 319  0       0    0      0    0
# 320  0       0    1      1    0
# 321  0       0    0      0    0
# 322  0       0    0      0    0
# 323  0       0    0      0    0
# 324  0       0    0      1    0
#
#         line  person  org  email  url  phone
# 338  Thanks!  0       0    0      0    0
# 340  Jenny    0       1    0      0    0
#
#          line  person  org  email  url  phone
# 351  Thanks,   0       0    0      0    0
# 353  Carla     1       0    0      0    0
#
#        line  person  org  email  url  phone
# 356  lisa    1       0    0      0    0
#
#                 line  person  org  email  url  phone
# 393  Thank you,       0       0    0      0    0
# 394                   0       0    0      0    0
# 395  Stephanie Sever  0       0    0      0    0
# 396  713-853-3465     0       0    0      0    1
#
#       line  person  org  email  url  phone
# 399  Jenny  0       1    0      0    0
#
#      line  person  org  email  url  phone
# 402  lisa  0       0    0      0    0
#
#      line  person  org  email  url  phone
# 405  Mark  0       0    0      0    0
#
#          line  person  org  email  url  phone
# 410  Ka'Tina-  0       0    0      0    0
#
#      line  person  org  email  url  phone
# 414  lisa  0       0    0      0    0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                           line  \
# 417  Amy Carpenter-Holmes
# 418  Swidler Berlin Shereff Friedman LLP
# 419  3000 K Street, N.W., Suite 300
# 420  Washington, DC  20007
# 421  Tel: (202) 424-7732  Fax: (202) 424-7647
# 422  AKHolmes@swidlaw.com
# 424  The preceding e-mail message contains information that is confidential, may be protected by the attorney/client or other applicable privilege, and may constitute non-public information.  It is intended to be conveyed only to the designated recipient(s).  If you are not an intended recipient, please notify the sender at 202-424-7541.  Unauthorized use, dissemination, distribution or reproduction of this message is strictly prohibited and may be unlawful.
#
#      person  org  email  url  phone
# 417  1       0    0      0    0
# 418  0       1    0      0    0
# 419  0       0    0      1    1
# 420  0       0    0      0    1
# 421  0       0    0      0    1
# 422  0       0    1      1    0
# 424  0       0    0      0    1
#
#                         line  person  org  email  url  phone
# 430  Mo Elafandi              1       0    0      0    0
# 431  Enron North America      0       1    0      0    0
# 432  121 SW Salmon, 3WTC0407  1       0    0      0    1
# 433  Portland, OR 97204       0       0    0      0    1
# 434  503-464-5106             0       0    0      0    1
# 435  Fax 503-464-7376         0       0    0      0    1
# 436  sCellular 503-860-8564   0       0    0      0    1
#
#                                                          line  person  org  \
# 440  Regards,                                                  0       0
# 441  Rudi                                                      1       0
# 442  PS  feel free to call me at 281-893-9984 with questions.  0       0
#
#      email  url  phone
# 440  0      0    0
# 441  0      0    0
# 442  0      0    1
#
#        line  person  org  email  url  phone
# 444  Darren  1       0    0      0    0
#
#                    line  person  org  email  url  phone
# 451  Thanks, Anne        0       0    0      0    0
# 452  (718) 403-2981      0       0    0      0    1
# 458  Thanks again, Anne  0       0    0      0    0
#
#                                            line  person  org  email  url  \
# 465  Thanks,                                     0       0    0      0
# 466  JP                                          0       0    0      0
# 467                                              0       0    0      0
# 468  Jeff Hoogendam - President & CEO            0       0    0      0
# 469  SmartPrice.com, Inc.                        0       1    0      1
# 470  "Changing the way the world buys telecom."  0       0    0      0
# 471  T: 512.342.8800, x3008                      0       0    0      0
# 472  F: 512.342.1072                             0       0    0      0
# 473  www.smartprice.com                          0       0    0      1
#
#      phone
# 465  0
# 466  0
# 467  0
# 468  0
# 469  0
# 470  0
# 471  1
# 472  1
# 473  0
#
#                               line  person  org  email  url  phone
# 484  -                              0       0    0      0    0
# 485  John R. Morris                 1       0    0      0    0
# 486  Vice President                 0       0    0      0    0
# 487  Economists Incorporated        0       0    0      0    0
# 488  1200 New Hampshire Avenue, NW  0       0    0      0    1
# 489  Suite 400                      0       0    0      0    0
# 490  Washington, DC? 20036          0       0    0      0    1
# 491  Voice: 202.223.4700            0       0    0      0    1
# 492  Fax:?? 202.296.7138            0       0    0      0    1

# %%
import spacy
nlp = spacy.load("en_core_web_md")

# %%
doc = nlp("Vice President")
[(ent, ent.label_) for ent in doc.ents]
# Out:
# []

# %% [markdown]
# ==============  ==========================================================================================
# Feature Name    Description
# ==============  ==========================================================================================
# low             Checks if the token is lower case.
# upper           Checks if the token is upper case.
# title           Checks if the token starts with an uppercase character and all remaining characters are
#                 lowercased.
# digit           Checks if the token contains just digits.
# prefix5         Take the first five characters of the token.
# prefix2         Take the first two characters of the token.
# suffix5         Take the last five characters of the token.
# suffix3         Take the last three characters of the token.
# suffix2         Take the last two characters of the token.
# suffix1         Take the last character of the token.
# pos             Take the Part-of-Speech tag of the token (``SpacyTokenizer`` required).
# pos2            Take the first two characters of the Part-of-Speech tag of the token
#                 (``SpacyTokenizer`` required).
# pattern         Take the patterns defined by ``RegexFeaturizer``.
# bias            Add an additional "bias" feature to the list of features.
# ==============  ==========================================================================================

# %%
master = pd.read_pickle("enron_random_clean1.pkl")

# %%
sigs = master[master.entity == 'signature']
sigs = sigs[master.blank == 0]
# Out:
# G:\Programs\Anaconda2\envs\thesis-enron\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
signature_blocks = {}

# %%
for name, group in sigs.groupby("filename"):
    signature_blocks[name] = "\n".join(group.line)

# %%
len(signature_blocks)
# Out:
# 116

# %%
import os
import spacy
import re
from collections import defaultdict

# %%
nlp = spacy.load("en_core_web_md")

# %%
def separate_entities(entities):
    separated = defaultdict(list)
    for ent in entities:
        if ent.label_ == "PERSON":
            separated["PERSON"].append(ent)
        if ent.label_ == "ORG":
            separated["ORG"].append(ent)
    return separated

# %%
RE_EMAIL = re.compile(
    r"(?:[a-z0-9!#$%&'*+/=?^_`{|}~-]+(?:\.[a-z0-9!#$%&'*+/=?^_`{|}~-]+)*|(?:[\x01-\x08\x0b\x0c\x0e-\x1f\x21\x23-\x5b\x5d-\x7f]|\\[\x01-\x09\x0b\x0c\x0e-\x7f])*)@(?:(?:[a-z0-9](?:[a-z0-9-]*[a-z0-9])?\.)+[a-z0-9](?:[a-z0-9-]*[a-z0-9])?|\[(?:(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)\.){3}(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?|[a-z0-9-]*[a-z0-9]:(?:[\x01-\x08\x0b\x0c\x0e-\x1f\x21-\x5a\x53-\x7f]|\\[\x01-\x09\x0b\x0c\x0e-\x7f])+)\])")
RE_URL = re.compile(r"((https?|ftp|smtp):\/\/)?(www.)?[a-z0-9]+\.[a-z]+(\/[a-zA-Z0-9#]+\/?)*", re.IGNORECASE)
RE_RELAX_PHONE = re.compile(r'(\(? ?[\d]{2,3} ?\)?.{,3}?){2,}')

# %%
for filename, text in signature_blocks.items():
    print(filename)
    path = os.path.join(r"F:\Documents\stopansko\masters\thesis\sig-detect\data\clean\enron_random_clean_signatures", filename)
    doc = nlp(text)
    separated_ents = separate_entities(doc.ents)
    new_text = text
    offset = 0
    for entity_type, ents in separated_ents.items():
        for ent in ents:
            start, end = ent.start_char + offset, ent.end_char + offset
            old_len = len(new_text)
            new_text = new_text[0:start] + f"[{new_text[start:end]}]({entity_type})" + new_text[end:]
            offset = len(new_text) - old_len

    match_map = {
        "EMAIL": RE_EMAIL.finditer(new_text, re.I),
        "PHONE": RE_RELAX_PHONE.finditer(new_text, re.I),
    }          
    
    with open(path, "w+", encoding="utf-8") as f:
        f.write(new_text+"\n\n\n\n\nOriginal:"+text)
# Out:
# allen-p_all_documents_113.txt
# allen-p_all_documents_171.txt
# allen-p_all_documents_496.txt
# allen-p_all_documents_505.txt
# allen-p_all_documents_595.txt
# allen-p_all_documents_599.txt
# allen-p_all_documents_90.txt
# arnold-j_all_documents_1027.txt
# arnold-j_all_documents_454.txt
# arnold-j_all_documents_687.txt
# arora-h_all_documents_44.txt
# arora-h_all_documents_58.txt
# arora-h_all_documents_64.txt
# badeer-r_all_documents_109.txt
# badeer-r_all_documents_119.txt
# badeer-r_all_documents_128.txt
# badeer-r_all_documents_141.txt
# badeer-r_all_documents_257.txt
# badeer-r_all_documents_274.txt
# badeer-r_all_documents_99.txt
# bailey-s_all_documents_14.txt
# bailey-s_all_documents_8.txt
